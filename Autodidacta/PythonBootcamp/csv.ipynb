# %% [markdown]
# CSV and PDFs

# %%
import csv

# %%
# Open File
data = open('clean_places.csv', encoding='utf-8')
#ENCODING IS IMPORTANT

# %%
csv_data = csv.reader(data)
data_lines = list(csv_data)

# %%
data_lines
# Out:
# [['',
#   'name',
#   'website',
#   'reviews_score',
#   'reviews_amount',
#   'phone',
#   'googlemaps_link',
#   'category',
#   'zone'],
#  ['2',
#   'IMPRONTA Estampados y Sublimados',
#   '0',
#   '5.0',
#   '134.0',
#   '03517664984',
#   'https://www.google.com/maps/place/IMPRONTA+Estampados+y+Sublimados/@-31.4222166,-64.4894671,11z/data=!4m11!1m3!2m2!1sEmpresa+de+sublimacion+y+estampado+en+Provincia+Cordoba+centro!6e6!3m6!1s0x943299915cfdde8b:0x9b178cb076fe30d5!8m2!3d-31.3830253!4d-64.1682051!!16s%2Fg%2F11q8xc28f3?entry=ttu',
#   'Empresa de sublimacion y estampado',
#   'Provincia Cordoba centro'],
#  ['3',
#   'ConVar Sublimación y Estampados',
#   '0',
#   '1.0',
#   '1.0',
#   '03517544354',
# ...

# %%
len(data_lines) # Amount of rows + head of csv
# Out:
# 34

# %%
data_lines[0]
# Out:
# ['',
#  'name',
#  'website',
#  'reviews_score',
#  'reviews_amount',
#  'phone',
#  'googlemaps_link',
#  'category',
#  'zone']

# %%
for line in data_lines[:10]:
    print(line)
# Out:
# ['', 'name', 'website', 'reviews_score', 'reviews_amount', 'phone', 'googlemaps_link', 'category', 'zone']
# ['2', 'IMPRONTA Estampados y Sublimados', '0', '5.0', '134.0', '03517664984', 'https://www.google.com/maps/place/IMPRONTA+Estampados+y+Sublimados/@-31.4222166,-64.4894671,11z/data=!4m11!1m3!2m2!1sEmpresa+de+sublimacion+y+estampado+en+Provincia+Cordoba+centro!6e6!3m6!1s0x943299915cfdde8b:0x9b178cb076fe30d5!8m2!3d-31.3830253!4d-64.1682051!!16s%2Fg%2F11q8xc28f3?entry=ttu', 'Empresa de sublimacion y estampado', 'Provincia Cordoba centro']
# ...
